# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet.plot import plot_plotly
import plotly.graph_objects as go

# %%
forecast = pd.read_csv("forecast_results.csv")

# %%
df=pd.read_csv("processed_sales.csv")

# %%
df.columns = ['ds', 'y']

# %%
from prophet import Prophet

# %%
model = Prophet()
model.fit(df)
# Out:
# 18:46:21 - cmdstanpy - INFO - Chain [1] start processing
# 18:46:21 - cmdstanpy - INFO - Chain [1] done processing

# %%
fig = model.plot(forecast)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:91, in check_isinstance(types, **kwargs)
#      90     names.append("None")
# ---> 91 raise TypeError(
#      92     "{!r} must be an instance of {}, not a {}".format(
#      93         k,
#      94         ", ".join(names[:-1]) + " or " + names[-1]
#      95         if len(names) > 1 else names[0],
#      96         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a int
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 fig = model.plot(forecast)
#       2 plt.show()
#
# File D:\Programs\Anaconda3\Lib\site-packages\prophet\forecaster.py:1886, in Prophet.plot(self, fcst, ax, uncertainty, plot_cap, xlabel, ylabel, figsize, include_legend)
#    1866 def plot(self, fcst, ax=None, uncertainty=True, plot_cap=True,
#    1867          xlabel='ds', ylabel='y', figsize=(10, 6), include_legend=False):
#    1868     """Plot the Prophet forecast.
#    1869
#    1870     Parameters
#    (...)
#    1884     A matplotlib figure.
#    1885     """
# -> 1886     return plot(
#    1887         m=self, fcst=fcst, ax=ax, uncertainty=uncertainty,
#    1888         plot_cap=plot_cap, xlabel=xlabel, ylabel=ylabel,
#    1889         figsize=figsize, include_legend=include_legend
#    1890     )
#
# File D:\Programs\Anaconda3\Lib\site-packages\prophet\plot.py:75, in plot(m, fcst, ax, uncertainty, plot_cap, xlabel, ylabel, figsize, include_legend)
#      72 fcst_t = fcst['ds']
#      73 ax.plot(m.history['ds'], m.history['y'], 'k.',
#      74         label='Observed data points')
# ---> 75 ax.plot(fcst_t, fcst['yhat'], ls='-', c='#0072B2', label='Forecast')
#      76 if 'cap' in fcst and plot_cap:
#      77     ax.plot(fcst_t, fcst['cap'], ls='--', c='k', label='Maximum capacity')
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axes\_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     x, y = index_of(xy[-1])
#     493 if axes.xaxis is not None:
# --> 494     axes.xaxis.update_units(x)
#     495 if axes.yaxis is not None:
#     496     axes.yaxis.update_units(y)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axis.py:1712, in Axis.update_units(self, data)
#    1710 neednew = self.converter != converter
#    1711 self.converter = converter
# -> 1712 default = self.converter.default_units(data, self)
#    1713 if default is not None and self.units is None:
#    1714     self.set_units(default)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axis.py:1792, in Axis.set_units(self, u)
#    1790 axis.units = u
#    1791 axis._update_axisinfo()
# -> 1792 axis.callbacks.process('units')
#    1793 axis.stale = True
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axes\_base.py:2461, in _AxesBase._unit_change_handler(self, axis_name, event)
#    2459 _api.check_in_list(self._axis_map, axis_name=axis_name)
#    2460 for line in self.lines:
# -> 2461     line.recache_always()
#    2462 self.relim()
#    2463 self._request_autoscale_view(axis_name)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\lines.py:664, in Line2D.recache_always(self)
#     663 def recache_always(self):
# --> 664     self.recache(always=True)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\lines.py:668, in Line2D.recache(self, always)
#     666 def recache(self, always=False):
#     667     if always or self._invalidx:
# --> 668         xconv = self.convert_xunits(self._xorig)
#     669         x = _to_unmasked_float_array(xconv).ravel()
#     670     else:
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\artist.py:279, in Artist.convert_xunits(self, x)
#     277 if ax is None or ax.xaxis is None:
#     278     return x
# --> 279 return ax.xaxis.convert_units(x)
#
# File D:\Programs\Anaconda3\Lib\site-packages\matplotlib\axis.py:1771, in Axis.convert_units(self, x)
#    1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
# -> 1771     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1772                                  f'units: {x!r}') from e
#    1773 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array(['2013-01-01T00:00:00.000000000', '2013-01-02T00:00:00.000000000',
#        '2013-01-03T00:00:00.000000000', ...,
#        '2017-08-13T00:00:00.000000000', '2017-08-14T00:00:00.000000000',
#        '2017-08-15T00:00:00.000000000'], dtype='datetime64[ns]')
